# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import gene_expression_data
gene_expression_data = pd.read_csv('gene_expression_data.csv', index_col=0)

# %%
gene_expression_data
# Out:
#                  GSM7500908_S001.Cel.gz  GSM7500909_S002.Cel.gz  \
# 1007_s_at                      2.977199                2.830919
# 1053_at                        2.564554                2.406084
# 117_at                         2.765110                2.716011
# 121_at                         3.209871                3.243258
# 1255_g_at                      1.867418                1.864083
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.240489                2.190432
# AFFX-ThrX-M_at                 2.012306                2.047211
# AFFX-TrpnX-3_at                1.819301                1.774937
# AFFX-TrpnX-5_at                1.971870                1.927410
# AFFX-TrpnX-M_at                2.005257                1.987641
#
#                  GSM7500910_S003.Cel.gz  GSM7500911_S004.Cel.gz  \
# 1007_s_at                      2.973773                2.965772
# 1053_at                        2.646121                2.683993
# 117_at                         2.779942                2.764771
# 121_at                         3.201516                3.211044
# 1255_g_at                      1.923635                1.946121
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.103839                2.191886
# AFFX-ThrX-M_at                 1.971929                2.015793
# AFFX-TrpnX-3_at                1.815607                1.802133
# AFFX-TrpnX-5_at                1.921539                1.941525
# AFFX-TrpnX-M_at                1.905453                2.036957
#
#                  GSM7500912_S005.Cel.gz  GSM7500913_S006.Cel.gz  \
# 1007_s_at                      2.907473                2.848492
# 1053_at                        2.541508                2.515903
# 117_at                         2.848162                2.819922
# 121_at                         3.201331                3.242932
# 1255_g_at                      1.893006                1.813685
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.235883                2.180236
# AFFX-ThrX-M_at                 2.035061                2.039806
# AFFX-TrpnX-3_at                1.782187                1.846286
# AFFX-TrpnX-5_at                1.943881                1.933769
# AFFX-TrpnX-M_at                2.086832                2.011879
#
#                  GSM7500914_S007.Cel.gz  GSM7500915_S008.Cel.gz  \
# 1007_s_at                      3.047869                2.990064
# 1053_at                        2.633083                2.559162
# 117_at                         2.801003                2.909639
# 121_at                         3.187960                3.226767
# 1255_g_at                      1.954318                1.986459
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.175774                2.234098
# AFFX-ThrX-M_at                 1.939412                2.097222
# AFFX-TrpnX-3_at                1.875413                1.816711
# AFFX-TrpnX-5_at                2.026743                1.986774
# AFFX-TrpnX-M_at                2.063535                2.029131
#
#                  GSM7500916_S009.Cel.gz  GSM7500917_S010.Cel.gz  ...  \
# 1007_s_at                      3.035037                2.851865  ...
# 1053_at                        2.533448                2.514448  ...
# 117_at                         2.738532                2.749105  ...
# 121_at                         3.239142                3.244321  ...
# 1255_g_at                      1.878160                1.809644  ...
# ...                                 ...                     ...  ...
# AFFX-ThrX-5_at                 2.221913                2.316419  ...
# AFFX-ThrX-M_at                 2.094999                2.059822  ...
# AFFX-TrpnX-3_at                1.769342                1.759787  ...
# AFFX-TrpnX-5_at                1.950995                1.883801  ...
# AFFX-TrpnX-M_at                2.018579                2.022000  ...
#
#                  GSM7501256_P030.Cel.gz  GSM7501257_P031.Cel.gz  \
# 1007_s_at                      2.980133                3.052230
# 1053_at                        2.812184                2.841988
# 117_at                         2.715693                2.534810
# 121_at                         3.036753                3.070189
# 1255_g_at                      1.896282                1.871552
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.210294                2.226333
# AFFX-ThrX-M_at                 1.993886                2.165017
# AFFX-TrpnX-3_at                1.818381                1.866763
# AFFX-TrpnX-5_at                1.901402                2.010583
# AFFX-TrpnX-M_at                1.989098                1.933010
#
#                  GSM7501258_P032.Cel.gz  GSM7501259_P033.Cel.gz  \
# 1007_s_at                      2.969792                2.983177
# 1053_at                        2.923152                2.822557
# 117_at                         2.594991                2.689233
# 121_at                         2.971118                3.072198
# 1255_g_at                      1.830172                1.886084
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.167406                2.173457
# AFFX-ThrX-M_at                 1.989295                1.994482
# AFFX-TrpnX-3_at                1.801350                1.821500
# AFFX-TrpnX-5_at                1.925953                1.977272
# AFFX-TrpnX-M_at                1.911018                1.989357
#
#                  GSM7501260_P034.Cel.gz  GSM7501261_P035.Cel.gz  \
# 1007_s_at                      2.751656                2.940429
# 1053_at                        2.820603                2.718132
# 117_at                         2.637799                2.704712
# 121_at                         3.033752                3.054938
# 1255_g_at                      1.821142                1.834628
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.267394                2.262799
# AFFX-ThrX-M_at                 2.033529                1.940855
# AFFX-TrpnX-3_at                1.842699                1.834753
# AFFX-TrpnX-5_at                1.871901                1.917734
# AFFX-TrpnX-M_at                1.880332                1.989553
#
#                  GSM7501262_P036.Cel.gz  GSM7501263_P037.Cel.gz  \
# 1007_s_at                      2.971834                2.985284
# 1053_at                        2.786440                2.846095
# 117_at                         2.712130                2.699143
# 121_at                         3.007769                3.050060
# 1255_g_at                      1.816625                1.862027
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.161119                2.344585
# AFFX-ThrX-M_at                 2.077009                2.004962
# AFFX-TrpnX-3_at                1.861306                1.893372
# AFFX-TrpnX-5_at                1.920578                1.965883
# AFFX-TrpnX-M_at                1.920899                1.941255
#
#                  GSM7501264_P038.Cel.gz  GSM7501265_P039.Cel.gz
# 1007_s_at                      2.887022                3.093719
# 1053_at                        2.771997                2.759746
# 117_at                         2.588294                2.533761
# 121_at                         3.072207                3.030860
# 1255_g_at                      1.877833                1.789541
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.193342                2.166979
# AFFX-ThrX-M_at                 1.985651                1.992523
# AFFX-TrpnX-3_at                1.809090                1.833230
# AFFX-TrpnX-5_at                1.971777                1.908649
# AFFX-TrpnX-M_at                1.926345                1.900918
#
# [54675 rows x 358 columns]

# %%
gene_expression_data

# applu log2 transformation to gene_expression_data
#gene_expression_data = np.log2(gene_expression_data)
# Out:
#                  GSM7500908_S001.Cel.gz  GSM7500909_S002.Cel.gz  \
# 1007_s_at                      2.977199                2.830919
# 1053_at                        2.564554                2.406084
# 117_at                         2.765110                2.716011
# 121_at                         3.209871                3.243258
# 1255_g_at                      1.867418                1.864083
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.240489                2.190432
# AFFX-ThrX-M_at                 2.012306                2.047211
# AFFX-TrpnX-3_at                1.819301                1.774937
# AFFX-TrpnX-5_at                1.971870                1.927410
# AFFX-TrpnX-M_at                2.005257                1.987641
#
#                  GSM7500910_S003.Cel.gz  GSM7500911_S004.Cel.gz  \
# 1007_s_at                      2.973773                2.965772
# 1053_at                        2.646121                2.683993
# 117_at                         2.779942                2.764771
# 121_at                         3.201516                3.211044
# 1255_g_at                      1.923635                1.946121
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.103839                2.191886
# AFFX-ThrX-M_at                 1.971929                2.015793
# AFFX-TrpnX-3_at                1.815607                1.802133
# AFFX-TrpnX-5_at                1.921539                1.941525
# AFFX-TrpnX-M_at                1.905453                2.036957
#
#                  GSM7500912_S005.Cel.gz  GSM7500913_S006.Cel.gz  \
# 1007_s_at                      2.907473                2.848492
# 1053_at                        2.541508                2.515903
# 117_at                         2.848162                2.819922
# 121_at                         3.201331                3.242932
# 1255_g_at                      1.893006                1.813685
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.235883                2.180236
# AFFX-ThrX-M_at                 2.035061                2.039806
# AFFX-TrpnX-3_at                1.782187                1.846286
# AFFX-TrpnX-5_at                1.943881                1.933769
# AFFX-TrpnX-M_at                2.086832                2.011879
#
#                  GSM7500914_S007.Cel.gz  GSM7500915_S008.Cel.gz  \
# 1007_s_at                      3.047869                2.990064
# 1053_at                        2.633083                2.559162
# 117_at                         2.801003                2.909639
# 121_at                         3.187960                3.226767
# 1255_g_at                      1.954318                1.986459
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.175774                2.234098
# AFFX-ThrX-M_at                 1.939412                2.097222
# AFFX-TrpnX-3_at                1.875413                1.816711
# AFFX-TrpnX-5_at                2.026743                1.986774
# AFFX-TrpnX-M_at                2.063535                2.029131
#
#                  GSM7500916_S009.Cel.gz  GSM7500917_S010.Cel.gz  ...  \
# 1007_s_at                      3.035037                2.851865  ...
# 1053_at                        2.533448                2.514448  ...
# 117_at                         2.738532                2.749105  ...
# 121_at                         3.239142                3.244321  ...
# 1255_g_at                      1.878160                1.809644  ...
# ...                                 ...                     ...  ...
# AFFX-ThrX-5_at                 2.221913                2.316419  ...
# AFFX-ThrX-M_at                 2.094999                2.059822  ...
# AFFX-TrpnX-3_at                1.769342                1.759787  ...
# AFFX-TrpnX-5_at                1.950995                1.883801  ...
# AFFX-TrpnX-M_at                2.018579                2.022000  ...
#
#                  GSM7501256_P030.Cel.gz  GSM7501257_P031.Cel.gz  \
# 1007_s_at                      2.980133                3.052230
# 1053_at                        2.812184                2.841988
# 117_at                         2.715693                2.534810
# 121_at                         3.036753                3.070189
# 1255_g_at                      1.896282                1.871552
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.210294                2.226333
# AFFX-ThrX-M_at                 1.993886                2.165017
# AFFX-TrpnX-3_at                1.818381                1.866763
# AFFX-TrpnX-5_at                1.901402                2.010583
# AFFX-TrpnX-M_at                1.989098                1.933010
#
#                  GSM7501258_P032.Cel.gz  GSM7501259_P033.Cel.gz  \
# 1007_s_at                      2.969792                2.983177
# 1053_at                        2.923152                2.822557
# 117_at                         2.594991                2.689233
# 121_at                         2.971118                3.072198
# 1255_g_at                      1.830172                1.886084
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.167406                2.173457
# AFFX-ThrX-M_at                 1.989295                1.994482
# AFFX-TrpnX-3_at                1.801350                1.821500
# AFFX-TrpnX-5_at                1.925953                1.977272
# AFFX-TrpnX-M_at                1.911018                1.989357
#
#                  GSM7501260_P034.Cel.gz  GSM7501261_P035.Cel.gz  \
# 1007_s_at                      2.751656                2.940429
# 1053_at                        2.820603                2.718132
# 117_at                         2.637799                2.704712
# 121_at                         3.033752                3.054938
# 1255_g_at                      1.821142                1.834628
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.267394                2.262799
# AFFX-ThrX-M_at                 2.033529                1.940855
# AFFX-TrpnX-3_at                1.842699                1.834753
# AFFX-TrpnX-5_at                1.871901                1.917734
# AFFX-TrpnX-M_at                1.880332                1.989553
#
#                  GSM7501262_P036.Cel.gz  GSM7501263_P037.Cel.gz  \
# 1007_s_at                      2.971834                2.985284
# 1053_at                        2.786440                2.846095
# 117_at                         2.712130                2.699143
# 121_at                         3.007769                3.050060
# 1255_g_at                      1.816625                1.862027
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.161119                2.344585
# AFFX-ThrX-M_at                 2.077009                2.004962
# AFFX-TrpnX-3_at                1.861306                1.893372
# AFFX-TrpnX-5_at                1.920578                1.965883
# AFFX-TrpnX-M_at                1.920899                1.941255
#
#                  GSM7501264_P038.Cel.gz  GSM7501265_P039.Cel.gz
# 1007_s_at                      2.887022                3.093719
# 1053_at                        2.771997                2.759746
# 117_at                         2.588294                2.533761
# 121_at                         3.072207                3.030860
# 1255_g_at                      1.877833                1.789541
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 2.193342                2.166979
# AFFX-ThrX-M_at                 1.985651                1.992523
# AFFX-TrpnX-3_at                1.809090                1.833230
# AFFX-TrpnX-5_at                1.971777                1.908649
# AFFX-TrpnX-M_at                1.926345                1.900918
#
# [54675 rows x 358 columns]

# %%
probeset_names = ["234764_x_at", "211835_at", "1561937_x_at", "202716_at",
                  "235305_s_at", "210538_s_at", "237461_at", "41660_at", "217892_s_at", 
                  "225822_at", "57532_at", "213489_at", "222641_s_at", "205159_at",
                  "209012_at", "220522_at", "223709_s_at", "36129_at",
                  "201848_s_at", "212704_at", "213622_at", "232531_at", 
                  "205666_at", "210789_x_at", "217809_at", "225291_at", 
                  "226488_at", "231131_at", "238662_at", "226098_at", "202387_at",
                  "228217_s_at", "225553_at", "223995_at", "202613_at", "203200_s_at"]
# Ext

# %%
probset_expression_data = gene_expression_data.loc[probeset_names]

probset_expression_data.shape
# Out:
# (36, 358)

# %%
# Create a heatmap of the probset_expression_data
plt.figure(figsize=(10, 3))
plt.imshow(probset_expression_data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
down_regulated = ["234764_x_at", "211835_at", "1561937_x_at", "202716_at", 
                  "235305_s_at", "210538_s_at", "237461_at", "41660_at", "217892_s_at",
                  "225822_at", "57532_at", "213489_at", "222641_s_at", "205159_at", "209012_at",
                  "220522_at", "223709_s_at", "36129_at", "201848_s_at", "212704_at", "213622_at",
                  "232531_at", "205666_at", "210789_x_at"]

# Calculate the average expression for Up-Regulated Probesets
up_regulated = ["217809_at", "225291_at", "226488_at", "231131_at",
                "238662_at", "226098_at", "202387_at", "228217_s_at",
                "225553_at", "223995_at", "202613_at", "203200_s_at"]

# %%
probset_down_regulated = probset_expression_data.loc[down_regulated]

probset_up_regulated = probset_expression_data.loc[up_regulated]

# get difference between up and down regulated
diff = probset_up_regulated.mean(axis=0) - probset_down_regulated.mean(axis=0)


diff = diff.sort_values(ascending=False)

diff
# Out:
# GSM7501168_S261.Cel.gz    0.424983
# GSM7501264_P038.Cel.gz    0.375796
# GSM7501260_P034.Cel.gz    0.336804
# GSM7501265_P039.Cel.gz    0.310186
# GSM7501254_P028.Cel.gz    0.305926
#                             ...
# GSM7500929_S022.Cel.gz   -0.266592
# GSM7500981_S074.Cel.gz   -0.269170
# GSM7500915_S008.Cel.gz   -0.278635
# GSM7500994_S087.Cel.gz   -0.281262
# GSM7500947_S040.Cel.gz   -0.292506
# Length: 358, dtype: float64

# %%
mgus_patients_risk = {}
for i in range(len(diff)):
    if diff[i] > 0.7:
        # append to patient i risk high
        mgus_patients_risk[i] = "High risk MGUS"
    else:
        mgus_patients_risk[i] = "Low risk MGUS"
        
mgus_patients_risk
# Out:
# C:\Users\cenzo\AppData\Local\Temp\ipykernel_3448\272575413.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if diff[i] > 0.7:
# {0: 'Low risk MGUS',
#  1: 'Low risk MGUS',
#  2: 'Low risk MGUS',
#  3: 'Low risk MGUS',
#  4: 'Low risk MGUS',
#  5: 'Low risk MGUS',
#  6: 'Low risk MGUS',
#  7: 'Low risk MGUS',
#  8: 'Low risk MGUS',
#  9: 'Low risk MGUS',
#  10: 'Low risk MGUS',
#  11: 'Low risk MGUS',
#  12: 'Low risk MGUS',
#  13: 'Low risk MGUS',
#  14: 'Low risk MGUS',
#  15: 'Low risk MGUS',
#  16: 'Low risk MGUS',
#  17: 'Low risk MGUS',
#  18: 'Low risk MGUS',
#  19: 'Low risk MGUS',
#  20: 'Low risk MGUS',
#  21: 'Low risk MGUS',
#  22: 'Low risk MGUS',
#  23: 'Low risk MGUS',
#  24: 'Low risk MGUS',
#  25: 'Low risk MGUS',
#  26: 'Low risk MGUS',
#  27: 'Low risk MGUS',
#  28: 'Low risk MGUS',
#  29: 'Low risk MGUS',
#  30: 'Low risk MGUS',
#  31: 'Low risk MGUS',
#  32: 'Low risk MGUS',
#  33: 'Low risk MGUS',
#  34: 'Low risk MGUS',
#  35: 'Low risk MGUS',
#  36: 'Low risk MGUS',
#  37: 'Low risk MGUS',
#  38: 'Low risk MGUS',
#  39: 'Low risk MGUS',
#  40: 'Low risk MGUS',
#  41: 'Low risk MGUS',
#  42: 'Low risk MGUS',
#  43: 'Low risk MGUS',
#  44: 'Low risk MGUS',
#  45: 'Low risk MGUS',
#  46: 'Low risk MGUS',
#  47: 'Low risk MGUS',
#  48: 'Low risk MGUS',
#  49: 'Low risk MGUS',
#  50: 'Low risk MGUS',
#  51: 'Low risk MGUS',
#  52: 'Low risk MGUS',
#  53: 'Low risk MGUS',
#  54: 'Low risk MGUS',
#  55: 'Low risk MGUS',
#  56: 'Low risk MGUS',
#  57: 'Low risk MGUS',
#  58: 'Low risk MGUS',
#  59: 'Low risk MGUS',
#  60: 'Low risk MGUS',
#  61: 'Low risk MGUS',
#  62: 'Low risk MGUS',
#  63: 'Low risk MGUS',
#  64: 'Low risk MGUS',
#  65: 'Low risk MGUS',
#  66: 'Low risk MGUS',
#  67: 'Low risk MGUS',
#  68: 'Low risk MGUS',
#  69: 'Low risk MGUS',
#  70: 'Low risk MGUS',
#  71: 'Low risk MGUS',
#  72: 'Low risk MGUS',
#  73: 'Low risk MGUS',
#  74: 'Low risk MGUS',
#  75: 'Low risk MGUS',
#  76: 'Low risk MGUS',
#  77: 'Low risk MGUS',
#  78: 'Low risk MGUS',
#  79: 'Low risk MGUS',
#  80: 'Low risk MGUS',
#  81: 'Low risk MGUS',
#  82: 'Low risk MGUS',
#  83: 'Low risk MGUS',
#  84: 'Low risk MGUS',
#  85: 'Low risk MGUS',
#  86: 'Low risk MGUS',
#  87: 'Low risk MGUS',
#  88: 'Low risk MGUS',
#  89: 'Low risk MGUS',
#  90: 'Low risk MGUS',
#  91: 'Low risk MGUS',
#  92: 'Low risk MGUS',
#  93: 'Low risk MGUS',
#  94: 'Low risk MGUS',
#  95: 'Low risk MGUS',
#  96: 'Low risk MGUS',
#  97: 'Low risk MGUS',
#  98: 'Low risk MGUS',
#  99: 'Low risk MGUS',
#  100: 'Low risk MGUS',
#  101: 'Low risk MGUS',
#  102: 'Low risk MGUS',
#  103: 'Low risk MGUS',
#  104: 'Low risk MGUS',
#  105: 'Low risk MGUS',
#  106: 'Low risk MGUS',
#  107: 'Low risk MGUS',
#  108: 'Low risk MGUS',
#  109: 'Low risk MGUS',
#  110: 'Low risk MGUS',
#  111: 'Low risk MGUS',
#  112: 'Low risk MGUS',
#  113: 'Low risk MGUS',
#  114: 'Low risk MGUS',
#  115: 'Low risk MGUS',
#  116: 'Low risk MGUS',
#  117: 'Low risk MGUS',
#  118: 'Low risk MGUS',
#  119: 'Low risk MGUS',
#  120: 'Low risk MGUS',
#  121: 'Low risk MGUS',
#  122: 'Low risk MGUS',
#  123: 'Low risk MGUS',
#  124: 'Low risk MGUS',
#  125: 'Low risk MGUS',
#  126: 'Low risk MGUS',
#  127: 'Low risk MGUS',
#  128: 'Low risk MGUS',
#  129: 'Low risk MGUS',
#  130: 'Low risk MGUS',
#  131: 'Low risk MGUS',
#  132: 'Low risk MGUS',
#  133: 'Low risk MGUS',
#  134: 'Low risk MGUS',
#  135: 'Low risk MGUS',
#  136: 'Low risk MGUS',
#  137: 'Low risk MGUS',
#  138: 'Low risk MGUS',
#  139: 'Low risk MGUS',
#  140: 'Low risk MGUS',
#  141: 'Low risk MGUS',
#  142: 'Low risk MGUS',
#  143: 'Low risk MGUS',
#  144: 'Low risk MGUS',
#  145: 'Low risk MGUS',
#  146: 'Low risk MGUS',
#  147: 'Low risk MGUS',
#  148: 'Low risk MGUS',
#  149: 'Low risk MGUS',
#  150: 'Low risk MGUS',
#  151: 'Low risk MGUS',
#  152: 'Low risk MGUS',
#  153: 'Low risk MGUS',
#  154: 'Low risk MGUS',
#  155: 'Low risk MGUS',
#  156: 'Low risk MGUS',
#  157: 'Low risk MGUS',
#  158: 'Low risk MGUS',
#  159: 'Low risk MGUS',
#  160: 'Low risk MGUS',
#  161: 'Low risk MGUS',
#  162: 'Low risk MGUS',
#  163: 'Low risk MGUS',
#  164: 'Low risk MGUS',
#  165: 'Low risk MGUS',
#  166: 'Low risk MGUS',
#  167: 'Low risk MGUS',
#  168: 'Low risk MGUS',
#  169: 'Low risk MGUS',
#  170: 'Low risk MGUS',
#  171: 'Low risk MGUS',
#  172: 'Low risk MGUS',
#  173: 'Low risk MGUS',
#  174: 'Low risk MGUS',
#  175: 'Low risk MGUS',
#  176: 'Low risk MGUS',
#  177: 'Low risk MGUS',
#  178: 'Low risk MGUS',
#  179: 'Low risk MGUS',
#  180: 'Low risk MGUS',
#  181: 'Low risk MGUS',
#  182: 'Low risk MGUS',
#  183: 'Low risk MGUS',
#  184: 'Low risk MGUS',
#  185: 'Low risk MGUS',
#  186: 'Low risk MGUS',
#  187: 'Low risk MGUS',
#  188: 'Low risk MGUS',
#  189: 'Low risk MGUS',
#  190: 'Low risk MGUS',
#  191: 'Low risk MGUS',
#  192: 'Low risk MGUS',
#  193: 'Low risk MGUS',
#  194: 'Low risk MGUS',
#  195: 'Low risk MGUS',
#  196: 'Low risk MGUS',
#  197: 'Low risk MGUS',
#  198: 'Low risk MGUS',
#  199: 'Low risk MGUS',
#  200: 'Low risk MGUS',
#  201: 'Low risk MGUS',
#  202: 'Low risk MGUS',
#  203: 'Low risk MGUS',
#  204: 'Low risk MGUS',
#  205: 'Low risk MGUS',
#  206: 'Low risk MGUS',
#  207: 'Low risk MGUS',
#  208: 'Low risk MGUS',
#  209: 'Low risk MGUS',
#  210: 'Low risk MGUS',
#  211: 'Low risk MGUS',
#  212: 'Low risk MGUS',
#  213: 'Low risk MGUS',
#  214: 'Low risk MGUS',
#  215: 'Low risk MGUS',
#  216: 'Low risk MGUS',
#  217: 'Low risk MGUS',
#  218: 'Low risk MGUS',
#  219: 'Low risk MGUS',
#  220: 'Low risk MGUS',
#  221: 'Low risk MGUS',
#  222: 'Low risk MGUS',
#  223: 'Low risk MGUS',
#  224: 'Low risk MGUS',
#  225: 'Low risk MGUS',
#  226: 'Low risk MGUS',
#  227: 'Low risk MGUS',
#  228: 'Low risk MGUS',
#  229: 'Low risk MGUS',
#  230: 'Low risk MGUS',
#  231: 'Low risk MGUS',
#  232: 'Low risk MGUS',
#  233: 'Low risk MGUS',
#  234: 'Low risk MGUS',
#  235: 'Low risk MGUS',
#  236: 'Low risk MGUS',
#  237: 'Low risk MGUS',
#  238: 'Low risk MGUS',
#  239: 'Low risk MGUS',
#  240: 'Low risk MGUS',
#  241: 'Low risk MGUS',
#  242: 'Low risk MGUS',
#  243: 'Low risk MGUS',
#  244: 'Low risk MGUS',
#  245: 'Low risk MGUS',
#  246: 'Low risk MGUS',
#  247: 'Low risk MGUS',
#  248: 'Low risk MGUS',
#  249: 'Low risk MGUS',
#  250: 'Low risk MGUS',
#  251: 'Low risk MGUS',
#  252: 'Low risk MGUS',
#  253: 'Low risk MGUS',
#  254: 'Low risk MGUS',
#  255: 'Low risk MGUS',
#  256: 'Low risk MGUS',
#  257: 'Low risk MGUS',
#  258: 'Low risk MGUS',
#  259: 'Low risk MGUS',
#  260: 'Low risk MGUS',
#  261: 'Low risk MGUS',
#  262: 'Low risk MGUS',
#  263: 'Low risk MGUS',
#  264: 'Low risk MGUS',
#  265: 'Low risk MGUS',
#  266: 'Low risk MGUS',
#  267: 'Low risk MGUS',
#  268: 'Low risk MGUS',
#  269: 'Low risk MGUS',
#  270: 'Low risk MGUS',
#  271: 'Low risk MGUS',
#  272: 'Low risk MGUS',
#  273: 'Low risk MGUS',
#  274: 'Low risk MGUS',
#  275: 'Low risk MGUS',
#  276: 'Low risk MGUS',
#  277: 'Low risk MGUS',
#  278: 'Low risk MGUS',
#  279: 'Low risk MGUS',
#  280: 'Low risk MGUS',
#  281: 'Low risk MGUS',
#  282: 'Low risk MGUS',
#  283: 'Low risk MGUS',
#  284: 'Low risk MGUS',
#  285: 'Low risk MGUS',
#  286: 'Low risk MGUS',
#  287: 'Low risk MGUS',
#  288: 'Low risk MGUS',
#  289: 'Low risk MGUS',
#  290: 'Low risk MGUS',
#  291: 'Low risk MGUS',
#  292: 'Low risk MGUS',
#  293: 'Low risk MGUS',
#  294: 'Low risk MGUS',
#  295: 'Low risk MGUS',
#  296: 'Low risk MGUS',
#  297: 'Low risk MGUS',
#  298: 'Low risk MGUS',
#  299: 'Low risk MGUS',
#  300: 'Low risk MGUS',
#  301: 'Low risk MGUS',
#  302: 'Low risk MGUS',
#  303: 'Low risk MGUS',
#  304: 'Low risk MGUS',
#  305: 'Low risk MGUS',
#  306: 'Low risk MGUS',
#  307: 'Low risk MGUS',
#  308: 'Low risk MGUS',
#  309: 'Low risk MGUS',
#  310: 'Low risk MGUS',
#  311: 'Low risk MGUS',
#  312: 'Low risk MGUS',
#  313: 'Low risk MGUS',
#  314: 'Low risk MGUS',
#  315: 'Low risk MGUS',
#  316: 'Low risk MGUS',
#  317: 'Low risk MGUS',
#  318: 'Low risk MGUS',
#  319: 'Low risk MGUS',
#  320: 'Low risk MGUS',
#  321: 'Low risk MGUS',
#  322: 'Low risk MGUS',
#  323: 'Low risk MGUS',
#  324: 'Low risk MGUS',
#  325: 'Low risk MGUS',
#  326: 'Low risk MGUS',
#  327: 'Low risk MGUS',
#  328: 'Low risk MGUS',
#  329: 'Low risk MGUS',
#  330: 'Low risk MGUS',
#  331: 'Low risk MGUS',
#  332: 'Low risk MGUS',
#  333: 'Low risk MGUS',
#  334: 'Low risk MGUS',
#  335: 'Low risk MGUS',
#  336: 'Low risk MGUS',
#  337: 'Low risk MGUS',
#  338: 'Low risk MGUS',
#  339: 'Low risk MGUS',
#  340: 'Low risk MGUS',
#  341: 'Low risk MGUS',
#  342: 'Low risk MGUS',
#  343: 'Low risk MGUS',
#  344: 'Low risk MGUS',
#  345: 'Low risk MGUS',
#  346: 'Low risk MGUS',
#  347: 'Low risk MGUS',
#  348: 'Low risk MGUS',
#  349: 'Low risk MGUS',
#  350: 'Low risk MGUS',
#  351: 'Low risk MGUS',
#  352: 'Low risk MGUS',
#  353: 'Low risk MGUS',
#  354: 'Low risk MGUS',
#  355: 'Low risk MGUS',
#  356: 'Low risk MGUS',
#  357: 'Low risk MGUS'}

# %%
random_genes.shape
# Out:
# (3000, 358)

# %%
random_genes.T
# Out:
#                         204025_s_at  237934_at  1561893_at  1554015_a_at  \
# GSM7500908_S001.Cel.gz     2.360034   2.425566    2.428845      2.615114
# GSM7500909_S002.Cel.gz     2.296002   2.406573    2.459088      2.720034
# GSM7500910_S003.Cel.gz     2.584218   2.411875    2.071316      2.734609
# GSM7500911_S004.Cel.gz     2.523418   2.366327    2.016676      2.825714
# GSM7500912_S005.Cel.gz     2.506688   2.386025    2.308418      2.539385
# ...                             ...        ...         ...           ...
# GSM7501261_P035.Cel.gz     2.851589   2.259736    2.115429      2.917746
# GSM7501262_P036.Cel.gz     2.993933   2.341998    2.163184      3.027395
# GSM7501263_P037.Cel.gz     3.042867   2.290956    2.167777      2.925771
# GSM7501264_P038.Cel.gz     3.165871   2.255493    2.363514      2.892109
# GSM7501265_P039.Cel.gz     2.946497   2.349240    2.183769      2.969071
#
#                         223451_s_at  215818_at  242749_at  1554391_at  \
# GSM7500908_S001.Cel.gz     2.802415   2.690071   2.888145    2.616002
# GSM7500909_S002.Cel.gz     2.626223   2.737399   2.904627    2.675231
# GSM7500910_S003.Cel.gz     2.814773   2.722355   2.919566    2.655530
# GSM7500911_S004.Cel.gz     2.798870   2.692207   2.889163    2.637589
# GSM7500912_S005.Cel.gz     2.943796   2.694567   2.925939    2.676812
# ...                             ...        ...        ...         ...
# GSM7501261_P035.Cel.gz     3.101245   2.654301   2.815270    2.676983
# GSM7501262_P036.Cel.gz     3.099931   2.340298   2.659718    2.790518
# GSM7501263_P037.Cel.gz     3.006791   2.567694   2.609882    2.692850
# GSM7501264_P038.Cel.gz     2.886357   2.483810   2.744513    2.707804
# GSM7501265_P039.Cel.gz     3.011877   2.494793   2.775792    2.678149
#
#                         1563557_at  237083_at  ...  1556147_at  217860_at  \
# GSM7500908_S001.Cel.gz    2.266708   2.485305  ...    1.894339   2.896343
# GSM7500909_S002.Cel.gz    2.271301   2.488593  ...    2.120317   2.942038
# GSM7500910_S003.Cel.gz    2.035635   2.284827  ...    1.897226   3.029210
# GSM7500911_S004.Cel.gz    2.185503   2.459525  ...    1.803663   3.108446
# GSM7500912_S005.Cel.gz    2.284991   2.391530  ...    1.790368   2.909093
# ...                            ...        ...  ...         ...        ...
# GSM7501261_P035.Cel.gz    2.221868   2.608714  ...    1.883402   3.030059
# GSM7501262_P036.Cel.gz    2.253209   2.780912  ...    2.352053   3.186515
# GSM7501263_P037.Cel.gz    2.181309   2.679049  ...    1.859794   3.219373
# GSM7501264_P038.Cel.gz    2.096665   2.971369  ...    1.907576   3.260175
# GSM7501265_P039.Cel.gz    2.182413   2.732572  ...    2.103957   3.136034
#
#                         1558768_at  222182_s_at  219063_at  233024_at  \
# GSM7500908_S001.Cel.gz    2.684059     2.826909   2.860914   2.221056
# GSM7500909_S002.Cel.gz    2.779291     2.780561   2.716188   2.152822
# GSM7500910_S003.Cel.gz    2.830915     2.941707   2.829471   2.155011
# GSM7500911_S004.Cel.gz    2.814265     2.834751   2.738708   2.231222
# GSM7500912_S005.Cel.gz    2.700491     2.784302   2.816130   2.243004
# ...                            ...          ...        ...        ...
# GSM7501261_P035.Cel.gz    2.720542     3.234932   2.847969   2.269952
# GSM7501262_P036.Cel.gz    2.553502     3.171765   2.854844   2.228626
# GSM7501263_P037.Cel.gz    2.606961     3.223973   2.833220   2.133656
# GSM7501264_P038.Cel.gz    2.603470     3.274627   2.826600   2.181683
# GSM7501265_P039.Cel.gz    2.571145     3.306827   2.814913   2.218730
#
#                         225814_at  244599_at  210623_at  244004_at
# GSM7500908_S001.Cel.gz   3.096556   2.738941   2.647918   1.740504
# GSM7500909_S002.Cel.gz   3.054676   2.827615   2.506428   1.757620
# GSM7500910_S003.Cel.gz   3.247244   2.621415   2.543313   1.812083
# GSM7500911_S004.Cel.gz   3.167030   2.764855   2.527799   1.763555
# GSM7500912_S005.Cel.gz   3.353118   2.800929   2.656180   1.741726
# ...                           ...        ...        ...        ...
# GSM7501261_P035.Cel.gz   3.334979   2.941458   2.378706   1.721246
# GSM7501262_P036.Cel.gz   3.337052   3.081543   2.602792   1.775300
# GSM7501263_P037.Cel.gz   3.265826   3.071945   2.464703   1.735117
# GSM7501264_P038.Cel.gz   3.418571   2.843610   2.504920   1.714515
# GSM7501265_P039.Cel.gz   3.377565   2.700118   2.530928   1.738181
#
# [358 rows x 3000 columns]

# %%
# take random 1000 geners
random_genes = gene_expression_data.sample(3000)


# Get correlation matrix
correlation_matrix = random_genes.T.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 10))
plt.imshow(correlation_matrix, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
# Do heatmap of probset_expression_data
plt.figure(figsize=(10, 3))
plt.imshow(probset_expression_data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
# Compute variance across rows
variance = probset_expression_data.var(axis=1)

# Sort the variance
variance = variance.sort_values(ascending=False)

# Get the top 10 genes with the highest variance
top_genes = variance.head(200)
