# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import gene_expression_data
gene_expression_data = pd.read_csv('gene_expression_data.csv', index_col=0)

# %%
gene_expression_data
# Out:
#                  GSM7500908_S001.Cel.gz  GSM7500909_S002.Cel.gz  \
# 1007_s_at                      1.573956                1.501270
# 1053_at                        1.358708                1.266687
# 117_at                         1.467337                1.441489
# 121_at                         1.682516                1.697444
# 1255_g_at                      0.901045                0.898466
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.163814                1.131216
# AFFX-ThrX-M_at                 1.008850                1.033660
# AFFX-TrpnX-3_at                0.863384                0.827768
# AFFX-TrpnX-5_at                0.979565                0.946664
# AFFX-TrpnX-M_at                1.003787                0.991057
#
#                  GSM7500910_S003.Cel.gz  GSM7500911_S004.Cel.gz  \
# 1007_s_at                      1.572295                1.568408
# 1053_at                        1.403879                1.424381
# 117_at                         1.475055                1.467160
# 121_at                         1.678755                1.683042
# 1255_g_at                      0.943835                0.960602
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.073024                1.132173
# AFFX-ThrX-M_at                 0.979608                1.011347
# AFFX-TrpnX-3_at                0.860452                0.849705
# AFFX-TrpnX-5_at                0.942262                0.957190
# AFFX-TrpnX-M_at                0.930134                1.026416
#
#                  GSM7500912_S005.Cel.gz  GSM7500913_S006.Cel.gz  \
# 1007_s_at                      1.539766                1.510198
# 1053_at                        1.345685                1.331076
# 117_at                         1.510031                1.495655
# 121_at                         1.678672                1.697299
# 1255_g_at                      0.920679                0.858924
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.160845                1.124485
# AFFX-ThrX-M_at                 1.025072                1.028432
# AFFX-TrpnX-3_at                0.833648                0.884626
# AFFX-TrpnX-5_at                0.958940                0.951416
# AFFX-TrpnX-M_at                1.061314                1.008544
#
#                  GSM7500914_S007.Cel.gz  GSM7500915_S008.Cel.gz  \
# 1007_s_at                      1.607801                1.580176
# 1053_at                        1.396753                1.355672
# 117_at                         1.485943                1.540840
# 121_at                         1.672634                1.690089
# 1255_g_at                      0.966665                0.990199
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.121529                1.159693
# AFFX-ThrX-M_at                 0.955620                1.068480
# AFFX-TrpnX-3_at                0.907208                0.861329
# AFFX-TrpnX-5_at                1.019163                0.990428
# AFFX-TrpnX-M_at                1.045118                1.020862
#
#                  GSM7500916_S009.Cel.gz  GSM7500917_S010.Cel.gz  ...  \
# 1007_s_at                      1.601714                1.511906  ...
# 1053_at                        1.341102                1.330242  ...
# 117_at                         1.453403                1.458962  ...
# 121_at                         1.695612                1.697917  ...
# 1255_g_at                      0.909320                0.855706  ...
# ...                                 ...                     ...  ...
# AFFX-ThrX-5_at                 1.151803                1.211896  ...
# AFFX-ThrX-M_at                 1.066949                1.042520  ...
# AFFX-TrpnX-3_at                0.823213                0.815401  ...
# AFFX-TrpnX-5_at                0.964210                0.913647  ...
# AFFX-TrpnX-M_at                1.013340                1.015783  ...
#
#                  GSM7501256_P030.Cel.gz  GSM7501257_P031.Cel.gz  \
# 1007_s_at                      1.575377                1.609863
# 1053_at                        1.491691                1.506900
# 117_at                         1.441321                1.341877
# 121_at                         1.602530                1.618328
# 1255_g_at                      0.923173                0.904235
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.144239                1.154669
# AFFX-ThrX-M_at                 0.995583                1.114379
# AFFX-TrpnX-3_at                0.862654                0.900539
# AFFX-TrpnX-5_at                0.927063                1.007614
# AFFX-TrpnX-M_at                0.992114                0.950849
#
#                  GSM7501258_P032.Cel.gz  GSM7501259_P033.Cel.gz  \
# 1007_s_at                      1.570362                1.576850
# 1053_at                        1.547525                1.497003
# 117_at                         1.375730                1.427195
# 121_at                         1.571006                1.619271
# 1255_g_at                      0.871979                0.915394
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.115969                1.119991
# AFFX-ThrX-M_at                 0.992258                0.996014
# AFFX-TrpnX-3_at                0.849079                0.865127
# AFFX-TrpnX-5_at                0.945572                0.983512
# AFFX-TrpnX-M_at                0.934341                0.992303
#
#                  GSM7501260_P034.Cel.gz  GSM7501261_P035.Cel.gz  \
# 1007_s_at                      1.460300                1.556027
# 1053_at                        1.496004                1.442616
# 117_at                         1.399335                1.435475
# 121_at                         1.601103                1.611143
# 1255_g_at                      0.864844                0.875487
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.181035                1.178108
# AFFX-ThrX-M_at                 1.023985                0.956692
# AFFX-TrpnX-3_at                0.881821                0.875586
# AFFX-TrpnX-5_at                0.904504                0.939403
# AFFX-TrpnX-M_at                0.910988                0.992444
#
#                  GSM7501262_P036.Cel.gz  GSM7501263_P037.Cel.gz  \
# 1007_s_at                      1.571354                1.577868
# 1053_at                        1.478423                1.508984
# 117_at                         1.439426                1.432502
# 121_at                         1.588694                1.608838
# 1255_g_at                      0.861261                0.896874
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.111779                1.229332
# AFFX-ThrX-M_at                 1.054508                1.003575
# AFFX-TrpnX-3_at                0.896315                0.920958
# AFFX-TrpnX-5_at                0.941541                0.975177
# AFFX-TrpnX-M_at                0.941782                0.956990
#
#                  GSM7501264_P038.Cel.gz  GSM7501265_P039.Cel.gz
# 1007_s_at                      1.529582                1.629342
# 1053_at                        1.470926                1.464535
# 117_at                         1.372001                1.341281
# 121_at                         1.619276                1.599727
# 1255_g_at                      0.909069                0.839590
# ...                                 ...                     ...
# AFFX-ThrX-5_at                 1.133131                1.115685
# AFFX-ThrX-M_at                 0.989612                0.994597
# AFFX-TrpnX-3_at                0.855264                0.874388
# AFFX-TrpnX-5_at                0.979496                0.932551
# AFFX-TrpnX-M_at                0.945866                0.926696
#
# [54675 rows x 358 columns]

# %%
gene_expression_data

# applu log2 transformation to gene_expression_data
gene_expression_data = np.log2(gene_expression_data)

# %%
probeset_names = ["234764_x_at", "211835_at", "1561937_x_at", "202716_at",
                  "235305_s_at", "210538_s_at", "237461_at", "41660_at", "217892_s_at", 
                  "225822_at", "57532_at", "213489_at", "222641_s_at", "205159_at",
                  "209012_at", "220522_at", "223709_s_at", "36129_at",
                  "201848_s_at", "212704_at", "213622_at", "232531_at", 
                  "205666_at", "210789_x_at", "217809_at", "225291_at", 
                  "226488_at", "231131_at", "238662_at", "226098_at", "202387_at",
                  "228217_s_at", "225553_at", "223995_at", "202613_at", "203200_s_at"]
# Ext

# %%
probset_expression_data = gene_expression_data.loc[probeset_names]

probset_expression_data.shape
# Out:
# (36, 358)

# %%
# Create a heatmap of the probset_expression_data
plt.figure(figsize=(10, 3))
plt.imshow(probset_expression_data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
down_regulated = ["234764_x_at", "211835_at", "1561937_x_at", "202716_at", 
                  "235305_s_at", "210538_s_at", "237461_at", "41660_at", "217892_s_at",
                  "225822_at", "57532_at", "213489_at", "222641_s_at", "205159_at", "209012_at",
                  "220522_at", "223709_s_at", "36129_at", "201848_s_at", "212704_at", "213622_at",
                  "232531_at", "205666_at", "210789_x_at"]

# Calculate the average expression for Up-Regulated Probesets
up_regulated = ["217809_at", "225291_at", "226488_at", "231131_at",
                "238662_at", "226098_at", "202387_at", "228217_s_at",
                "225553_at", "223995_at", "202613_at", "203200_s_at"]

# %%
probset_down_regulated = probset_expression_data.loc[down_regulated]

probset_up_regulated = probset_expression_data.loc[up_regulated]

# get difference between up and down regulated
diff = probset_up_regulated.mean(axis=0) - probset_down_regulated.mean(axis=0)


diff = diff.sort_values(ascending=False)

diff
# Out:
# GSM7501168_S261.Cel.gz    0.215409
# GSM7501264_P038.Cel.gz    0.191269
# GSM7501260_P034.Cel.gz    0.169567
# GSM7501265_P039.Cel.gz    0.159906
# GSM7501251_P025.Cel.gz    0.154354
#                             ...
# GSM7500929_S022.Cel.gz   -0.135820
# GSM7500981_S074.Cel.gz   -0.136464
# GSM7500915_S008.Cel.gz   -0.141767
# GSM7500994_S087.Cel.gz   -0.144432
# GSM7500947_S040.Cel.gz   -0.150606
# Length: 358, dtype: float64

# %%
mgus_patients_risk = {}
for i in range(len(diff)):
    if diff[i] > 0.7:
        # append to patient i risk high
        mgus_patients_risk[i] = "High risk MGUS"
    else:
        mgus_patients_risk[i] = "Low risk MGUS"
        
mgus_patients_risk
# Out:
# C:\Users\cenzo\AppData\Local\Temp\ipykernel_17996\272575413.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if diff[i] > 0.7:
# {0: 'Low risk MGUS',
#  1: 'Low risk MGUS',
#  2: 'Low risk MGUS',
#  3: 'Low risk MGUS',
#  4: 'Low risk MGUS',
#  5: 'Low risk MGUS',
#  6: 'Low risk MGUS',
#  7: 'Low risk MGUS',
#  8: 'Low risk MGUS',
#  9: 'Low risk MGUS',
#  10: 'Low risk MGUS',
#  11: 'Low risk MGUS',
#  12: 'Low risk MGUS',
#  13: 'Low risk MGUS',
#  14: 'Low risk MGUS',
#  15: 'Low risk MGUS',
#  16: 'Low risk MGUS',
#  17: 'Low risk MGUS',
#  18: 'Low risk MGUS',
#  19: 'Low risk MGUS',
#  20: 'Low risk MGUS',
#  21: 'Low risk MGUS',
#  22: 'Low risk MGUS',
#  23: 'Low risk MGUS',
#  24: 'Low risk MGUS',
#  25: 'Low risk MGUS',
#  26: 'Low risk MGUS',
#  27: 'Low risk MGUS',
#  28: 'Low risk MGUS',
#  29: 'Low risk MGUS',
#  30: 'Low risk MGUS',
#  31: 'Low risk MGUS',
#  32: 'Low risk MGUS',
#  33: 'Low risk MGUS',
#  34: 'Low risk MGUS',
#  35: 'Low risk MGUS',
#  36: 'Low risk MGUS',
#  37: 'Low risk MGUS',
#  38: 'Low risk MGUS',
#  39: 'Low risk MGUS',
#  40: 'Low risk MGUS',
#  41: 'Low risk MGUS',
#  42: 'Low risk MGUS',
#  43: 'Low risk MGUS',
#  44: 'Low risk MGUS',
#  45: 'Low risk MGUS',
#  46: 'Low risk MGUS',
#  47: 'Low risk MGUS',
#  48: 'Low risk MGUS',
#  49: 'Low risk MGUS',
#  50: 'Low risk MGUS',
#  51: 'Low risk MGUS',
#  52: 'Low risk MGUS',
#  53: 'Low risk MGUS',
#  54: 'Low risk MGUS',
#  55: 'Low risk MGUS',
#  56: 'Low risk MGUS',
#  57: 'Low risk MGUS',
#  58: 'Low risk MGUS',
#  59: 'Low risk MGUS',
#  60: 'Low risk MGUS',
#  61: 'Low risk MGUS',
#  62: 'Low risk MGUS',
#  63: 'Low risk MGUS',
#  64: 'Low risk MGUS',
#  65: 'Low risk MGUS',
#  66: 'Low risk MGUS',
#  67: 'Low risk MGUS',
#  68: 'Low risk MGUS',
#  69: 'Low risk MGUS',
#  70: 'Low risk MGUS',
#  71: 'Low risk MGUS',
#  72: 'Low risk MGUS',
#  73: 'Low risk MGUS',
#  74: 'Low risk MGUS',
#  75: 'Low risk MGUS',
#  76: 'Low risk MGUS',
#  77: 'Low risk MGUS',
#  78: 'Low risk MGUS',
#  79: 'Low risk MGUS',
#  80: 'Low risk MGUS',
#  81: 'Low risk MGUS',
#  82: 'Low risk MGUS',
#  83: 'Low risk MGUS',
#  84: 'Low risk MGUS',
#  85: 'Low risk MGUS',
#  86: 'Low risk MGUS',
#  87: 'Low risk MGUS',
#  88: 'Low risk MGUS',
#  89: 'Low risk MGUS',
#  90: 'Low risk MGUS',
#  91: 'Low risk MGUS',
#  92: 'Low risk MGUS',
#  93: 'Low risk MGUS',
#  94: 'Low risk MGUS',
#  95: 'Low risk MGUS',
#  96: 'Low risk MGUS',
#  97: 'Low risk MGUS',
#  98: 'Low risk MGUS',
#  99: 'Low risk MGUS',
#  100: 'Low risk MGUS',
#  101: 'Low risk MGUS',
#  102: 'Low risk MGUS',
#  103: 'Low risk MGUS',
#  104: 'Low risk MGUS',
#  105: 'Low risk MGUS',
#  106: 'Low risk MGUS',
#  107: 'Low risk MGUS',
#  108: 'Low risk MGUS',
#  109: 'Low risk MGUS',
#  110: 'Low risk MGUS',
#  111: 'Low risk MGUS',
#  112: 'Low risk MGUS',
#  113: 'Low risk MGUS',
#  114: 'Low risk MGUS',
#  115: 'Low risk MGUS',
#  116: 'Low risk MGUS',
#  117: 'Low risk MGUS',
#  118: 'Low risk MGUS',
#  119: 'Low risk MGUS',
#  120: 'Low risk MGUS',
#  121: 'Low risk MGUS',
#  122: 'Low risk MGUS',
#  123: 'Low risk MGUS',
#  124: 'Low risk MGUS',
#  125: 'Low risk MGUS',
#  126: 'Low risk MGUS',
#  127: 'Low risk MGUS',
#  128: 'Low risk MGUS',
#  129: 'Low risk MGUS',
#  130: 'Low risk MGUS',
#  131: 'Low risk MGUS',
#  132: 'Low risk MGUS',
#  133: 'Low risk MGUS',
#  134: 'Low risk MGUS',
#  135: 'Low risk MGUS',
#  136: 'Low risk MGUS',
#  137: 'Low risk MGUS',
#  138: 'Low risk MGUS',
#  139: 'Low risk MGUS',
#  140: 'Low risk MGUS',
#  141: 'Low risk MGUS',
#  142: 'Low risk MGUS',
#  143: 'Low risk MGUS',
#  144: 'Low risk MGUS',
#  145: 'Low risk MGUS',
#  146: 'Low risk MGUS',
#  147: 'Low risk MGUS',
#  148: 'Low risk MGUS',
#  149: 'Low risk MGUS',
#  150: 'Low risk MGUS',
#  151: 'Low risk MGUS',
#  152: 'Low risk MGUS',
#  153: 'Low risk MGUS',
#  154: 'Low risk MGUS',
#  155: 'Low risk MGUS',
#  156: 'Low risk MGUS',
#  157: 'Low risk MGUS',
#  158: 'Low risk MGUS',
#  159: 'Low risk MGUS',
#  160: 'Low risk MGUS',
#  161: 'Low risk MGUS',
#  162: 'Low risk MGUS',
#  163: 'Low risk MGUS',
#  164: 'Low risk MGUS',
#  165: 'Low risk MGUS',
#  166: 'Low risk MGUS',
#  167: 'Low risk MGUS',
#  168: 'Low risk MGUS',
#  169: 'Low risk MGUS',
#  170: 'Low risk MGUS',
#  171: 'Low risk MGUS',
#  172: 'Low risk MGUS',
#  173: 'Low risk MGUS',
#  174: 'Low risk MGUS',
#  175: 'Low risk MGUS',
#  176: 'Low risk MGUS',
#  177: 'Low risk MGUS',
#  178: 'Low risk MGUS',
#  179: 'Low risk MGUS',
#  180: 'Low risk MGUS',
#  181: 'Low risk MGUS',
#  182: 'Low risk MGUS',
#  183: 'Low risk MGUS',
#  184: 'Low risk MGUS',
#  185: 'Low risk MGUS',
#  186: 'Low risk MGUS',
#  187: 'Low risk MGUS',
#  188: 'Low risk MGUS',
#  189: 'Low risk MGUS',
#  190: 'Low risk MGUS',
#  191: 'Low risk MGUS',
#  192: 'Low risk MGUS',
#  193: 'Low risk MGUS',
#  194: 'Low risk MGUS',
#  195: 'Low risk MGUS',
#  196: 'Low risk MGUS',
#  197: 'Low risk MGUS',
#  198: 'Low risk MGUS',
#  199: 'Low risk MGUS',
#  200: 'Low risk MGUS',
#  201: 'Low risk MGUS',
#  202: 'Low risk MGUS',
#  203: 'Low risk MGUS',
#  204: 'Low risk MGUS',
#  205: 'Low risk MGUS',
#  206: 'Low risk MGUS',
#  207: 'Low risk MGUS',
#  208: 'Low risk MGUS',
#  209: 'Low risk MGUS',
#  210: 'Low risk MGUS',
#  211: 'Low risk MGUS',
#  212: 'Low risk MGUS',
#  213: 'Low risk MGUS',
#  214: 'Low risk MGUS',
#  215: 'Low risk MGUS',
#  216: 'Low risk MGUS',
#  217: 'Low risk MGUS',
#  218: 'Low risk MGUS',
#  219: 'Low risk MGUS',
#  220: 'Low risk MGUS',
#  221: 'Low risk MGUS',
#  222: 'Low risk MGUS',
#  223: 'Low risk MGUS',
#  224: 'Low risk MGUS',
#  225: 'Low risk MGUS',
#  226: 'Low risk MGUS',
#  227: 'Low risk MGUS',
#  228: 'Low risk MGUS',
#  229: 'Low risk MGUS',
#  230: 'Low risk MGUS',
#  231: 'Low risk MGUS',
#  232: 'Low risk MGUS',
#  233: 'Low risk MGUS',
#  234: 'Low risk MGUS',
#  235: 'Low risk MGUS',
#  236: 'Low risk MGUS',
#  237: 'Low risk MGUS',
#  238: 'Low risk MGUS',
#  239: 'Low risk MGUS',
#  240: 'Low risk MGUS',
#  241: 'Low risk MGUS',
#  242: 'Low risk MGUS',
#  243: 'Low risk MGUS',
#  244: 'Low risk MGUS',
#  245: 'Low risk MGUS',
#  246: 'Low risk MGUS',
#  247: 'Low risk MGUS',
#  248: 'Low risk MGUS',
#  249: 'Low risk MGUS',
#  250: 'Low risk MGUS',
#  251: 'Low risk MGUS',
#  252: 'Low risk MGUS',
#  253: 'Low risk MGUS',
#  254: 'Low risk MGUS',
#  255: 'Low risk MGUS',
#  256: 'Low risk MGUS',
#  257: 'Low risk MGUS',
#  258: 'Low risk MGUS',
#  259: 'Low risk MGUS',
#  260: 'Low risk MGUS',
#  261: 'Low risk MGUS',
#  262: 'Low risk MGUS',
#  263: 'Low risk MGUS',
#  264: 'Low risk MGUS',
#  265: 'Low risk MGUS',
#  266: 'Low risk MGUS',
#  267: 'Low risk MGUS',
#  268: 'Low risk MGUS',
#  269: 'Low risk MGUS',
#  270: 'Low risk MGUS',
#  271: 'Low risk MGUS',
#  272: 'Low risk MGUS',
#  273: 'Low risk MGUS',
#  274: 'Low risk MGUS',
#  275: 'Low risk MGUS',
#  276: 'Low risk MGUS',
#  277: 'Low risk MGUS',
#  278: 'Low risk MGUS',
#  279: 'Low risk MGUS',
#  280: 'Low risk MGUS',
#  281: 'Low risk MGUS',
#  282: 'Low risk MGUS',
#  283: 'Low risk MGUS',
#  284: 'Low risk MGUS',
#  285: 'Low risk MGUS',
#  286: 'Low risk MGUS',
#  287: 'Low risk MGUS',
#  288: 'Low risk MGUS',
#  289: 'Low risk MGUS',
#  290: 'Low risk MGUS',
#  291: 'Low risk MGUS',
#  292: 'Low risk MGUS',
#  293: 'Low risk MGUS',
#  294: 'Low risk MGUS',
#  295: 'Low risk MGUS',
#  296: 'Low risk MGUS',
#  297: 'Low risk MGUS',
#  298: 'Low risk MGUS',
#  299: 'Low risk MGUS',
#  300: 'Low risk MGUS',
#  301: 'Low risk MGUS',
#  302: 'Low risk MGUS',
#  303: 'Low risk MGUS',
#  304: 'Low risk MGUS',
#  305: 'Low risk MGUS',
#  306: 'Low risk MGUS',
#  307: 'Low risk MGUS',
#  308: 'Low risk MGUS',
#  309: 'Low risk MGUS',
#  310: 'Low risk MGUS',
#  311: 'Low risk MGUS',
#  312: 'Low risk MGUS',
#  313: 'Low risk MGUS',
#  314: 'Low risk MGUS',
#  315: 'Low risk MGUS',
#  316: 'Low risk MGUS',
#  317: 'Low risk MGUS',
#  318: 'Low risk MGUS',
#  319: 'Low risk MGUS',
#  320: 'Low risk MGUS',
#  321: 'Low risk MGUS',
#  322: 'Low risk MGUS',
#  323: 'Low risk MGUS',
#  324: 'Low risk MGUS',
#  325: 'Low risk MGUS',
#  326: 'Low risk MGUS',
#  327: 'Low risk MGUS',
#  328: 'Low risk MGUS',
#  329: 'Low risk MGUS',
#  330: 'Low risk MGUS',
#  331: 'Low risk MGUS',
#  332: 'Low risk MGUS',
#  333: 'Low risk MGUS',
#  334: 'Low risk MGUS',
#  335: 'Low risk MGUS',
#  336: 'Low risk MGUS',
#  337: 'Low risk MGUS',
#  338: 'Low risk MGUS',
#  339: 'Low risk MGUS',
#  340: 'Low risk MGUS',
#  341: 'Low risk MGUS',
#  342: 'Low risk MGUS',
#  343: 'Low risk MGUS',
#  344: 'Low risk MGUS',
#  345: 'Low risk MGUS',
#  346: 'Low risk MGUS',
#  347: 'Low risk MGUS',
#  348: 'Low risk MGUS',
#  349: 'Low risk MGUS',
#  350: 'Low risk MGUS',
#  351: 'Low risk MGUS',
#  352: 'Low risk MGUS',
#  353: 'Low risk MGUS',
#  354: 'Low risk MGUS',
#  355: 'Low risk MGUS',
#  356: 'Low risk MGUS',
#  357: 'Low risk MGUS'}
