# %%
from pycaret.classification import *
import pandas as pd

# %%
# Import gene_expression_data
gene_expression_data = pd.read_csv('../data/gene_expression_data.csv', index_col=0)

gene_expression_data = gene_expression_data.T

# %%
gene_expression_data = gene_expression_data


# add column named state with progressing or stable if row contains _P or _S
for index, row in gene_expression_data.iterrows():
    if '_P' in index:
        gene_expression_data.loc[index, 'state'] = 1
    elif '_S' in index:
        gene_expression_data.loc[index, 'state'] = 0

# %%
probeset_names = ["234764_x_at", "211835_at", "1561937_x_at", "202716_at",
                  "235305_s_at", "210538_s_at", "237461_at", "41660_at", "217892_s_at", 
                  "225822_at", "57532_at", "213489_at", "222641_s_at", "205159_at",
                  "209012_at", "220522_at", "223709_s_at", "36129_at",
                  "201848_s_at", "212704_at", "213622_at", "232531_at", 
                  "205666_at", "210789_x_at", "217809_at", "225291_at", 
                  "226488_at", "231131_at", "238662_at", "226098_at", "202387_at",
                  "228217_s_at", "225553_at", "223995_at", "202613_at", "203200_s_at"]

# %%
len(probeset_names)
# Out:
# 36

# %%
s = setup(gene_expression_data,
          keep_features=probeset_names,
          target = 'state', 
          fix_imbalance=True,
          fix_imbalance_method="SMOTE",
          remove_multicollinearity=True,
          multicollinearity_threshold=.7,
          low_variance_threshold=.4,
          pca=True,
          pca_method='kernel',
          pca_components=45,
          feature_selection=True,
          feature_selection_method='sequential',
          fold=4,
          n_features_to_select=38,
          verbose=True,
          # use_gpu=True,
            )
# Out:
# <style type="text/css">
# #T_17490_row9_col1, #T_17490_row14_col1, #T_17490_row16_col1, #T_17490_row18_col1, #T_17490_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_17490">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17490_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_17490_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17490_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17490_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_17490_row0_col1" class="data row0 col1" >1577</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17490_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_17490_row1_col1" class="data row1 col1" >state</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_17490_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_17490_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17490_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_17490_row3_col1" class="data row3 col1" >(358, 54676)</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_17490_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_17490_row4_col1" class="data row4 col1" >(554, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_17490_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_17490_row5_col1" class="data row5 col1" >(446, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_17490_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_17490_row6_col1" class="data row6 col1" >(108, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_17490_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_17490_row7_col1" class="data row7 col1" >54675</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_17490_row8_col0" class="data row8 col0" >Keep features</td>
#       <td id="T_17490_row8_col1" class="data row8 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_17490_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_17490_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_17490_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_17490_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_17490_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_17490_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_17490_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_17490_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_17490_row13_col0" class="data row13 col0" >Low variance threshold</td>
#       <td id="T_17490_row13_col1" class="data row13 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_17490_row14_col0" class="data row14 col0" >Remove multicollinearity</td>
#       <td id="T_17490_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_17490_row15_col0" class="data row15 col0" >Multicollinearity threshold</td>
#       <td id="T_17490_row15_col1" class="data row15 col1" >0.700000</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_17490_row16_col0" class="data row16 col0" >Fix imbalance</td>
#       <td id="T_17490_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_17490_row17_col0" class="data row17 col0" >Fix imbalance method</td>
#       <td id="T_17490_row17_col1" class="data row17 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_17490_row18_col0" class="data row18 col0" >PCA</td>
#       <td id="T_17490_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_17490_row19_col0" class="data row19 col0" >PCA method</td>
#       <td id="T_17490_row19_col1" class="data row19 col1" >kernel</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_17490_row20_col0" class="data row20 col0" >PCA components</td>
#       <td id="T_17490_row20_col1" class="data row20 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_17490_row21_col0" class="data row21 col0" >Feature selection</td>
#       <td id="T_17490_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_17490_row22_col0" class="data row22 col0" >Feature selection method</td>
#       <td id="T_17490_row22_col1" class="data row22 col1" >sequential</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_17490_row23_col0" class="data row23 col0" >Feature selection estimator</td>
#       <td id="T_17490_row23_col1" class="data row23 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_17490_row24_col0" class="data row24 col0" >Number of features selected</td>
#       <td id="T_17490_row24_col1" class="data row24 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_17490_row25_col0" class="data row25 col0" >Fold Generator</td>
#       <td id="T_17490_row25_col1" class="data row25 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_17490_row26_col0" class="data row26 col0" >Fold Number</td>
#       <td id="T_17490_row26_col1" class="data row26 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_17490_row27_col0" class="data row27 col0" >CPU Jobs</td>
#       <td id="T_17490_row27_col1" class="data row27 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_17490_row28_col0" class="data row28 col0" >Use GPU</td>
#       <td id="T_17490_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_17490_row29_col0" class="data row29 col0" >Log Experiment</td>
#       <td id="T_17490_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_17490_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_17490_row30_col0" class="data row30 c

# %%
TX=get_config('dataset_transformed')

# %%
TX[TX['state'] > 0.5]
# Out:
#                         1561937_x_at  201848_s_at  202387_at  202613_at  \
# GSM7501265_P039.Cel.gz      2.873527     2.753061   3.231888   2.868800
# GSM7501234_P008.Cel.gz      3.029286     2.562512   3.151761   2.905101
# GSM7501240_P014.Cel.gz      3.159442     2.623927   3.043006   2.463778
# GSM7501236_P010.Cel.gz      3.381119     2.211044   3.212020   2.656841
# GSM7501243_P017.Cel.gz      2.835560     2.879845   3.125184   2.808245
# ...                              ...          ...        ...        ...
# GSM7501232_P006.Cel.gz      3.018958     2.567735   3.013868   2.625128
# GSM7501244_P018.Cel.gz      2.899926     2.648777   3.123609   2.591810
# GSM7501251_P025.Cel.gz      2.952867     2.590038   3.318040   2.778505
# GSM7501260_P034.Cel.gz      2.923971     2.806489   3.256408   2.954015
# GSM7501258_P032.Cel.gz      3.036291     2.662160   3.216707   2.700692
#
#                         202716_at  203200_s_at  205159_at  205666_at  \
# GSM7501265_P039.Cel.gz   3.341805     3.209658   2.737551   2.342865
# GSM7501234_P008.Cel.gz   3.122469     3.136738   3.283214   2.446913
# GSM7501240_P014.Cel.gz   2.864556     2.962289   2.740822   2.665799
# GSM7501236_P010.Cel.gz   3.178245     3.130063   3.290285   2.592488
# GSM7501243_P017.Cel.gz   2.966585     3.101252   2.436863   2.556443
# ...                           ...          ...        ...        ...
# GSM7501232_P006.Cel.gz   2.966894     3.102416   3.529537   2.649032
# GSM7501244_P018.Cel.gz   2.974082     3.032039   3.015479   2.679894
# GSM7501251_P025.Cel.gz   3.197240     3.208935   3.444444   2.358315
# GSM7501260_P034.Cel.gz   3.182364     3.294712   3.505084   2.446361
# GSM7501258_P032.Cel.gz   3.116864     3.309442   2.902082   2.356850
#
#                         209012_at  210538_s_at  ...  kernelpca35  kernelpca36  \
# GSM7501265_P039.Cel.gz   2.463258     3.341945  ...    -0.013005    -0.010448
# GSM7501234_P008.Cel.gz   2.793595     3.120377  ...     0.024319     0.013557
# GSM7501240_P014.Cel.gz   2.531246     2.867167  ...    -0.001699     0.002300
# GSM7501236_P010.Cel.gz   2.410816     3.463661  ...    -0.003012     0.005738
# GSM7501243_P017.Cel.gz   2.435719     3.199214  ...    -0.006097     0.002224
# ...                           ...          ...  ...          ...          ...
# GSM7501232_P006.Cel.gz   2.611279     2.655730  ...     0.004365     0.003234
# GSM7501244_P018.Cel.gz   2.404834     2.634478  ...     0.016635     0.013598
# GSM7501251_P025.Cel.gz   2.530356     3.392875  ...     0.007619     0.005284
# GSM7501260_P034.Cel.gz   2.701765     3.327125  ...    -0.008967    -0.003399
# GSM7501258_P032.Cel.gz   2.537444     3.259913  ...    -0.002082     0.001297
#
#                         kernelpca37  kernelpca39  kernelpca40  kernelpca41  \
# GSM7501265_P039.Cel.gz     0.000739     0.001564    -0.000887     0.000301
# GSM7501234_P008.Cel.gz    -0.003758     0.000459     0.010398    -0.003909
# GSM7501240_P014.Cel.gz    -0.003157     0.000801     0.000746     0.000091
# GSM7501236_P010.Cel.gz    -0.005150     0.000643    -0.000129     0.001896
# GSM7501243_P017.Cel.gz     0.004216     0.002585    -0.003849     0.002539
# ...                             ...          ...          ...          ...
# GSM7501232_P006.Cel.gz     0.004656     0.000096    -0.000134     0.000552
# GSM7501244_P018.Cel.gz    -0.003031     0.001046     0.008211    -0.003249
# GSM7501251_P025.Cel.gz     0.010227     0.006031     0.001624    -0.015728
# GSM7501260_P034.Cel.gz     0.009350    -0.005036     0.005645     0.000038
# GSM7501258_P032.Cel.gz    -0.006802     0.000808    -0.003968     0.001306
#
#                         kernelpca42  kernelpca43  kernelpca44  state
# GSM7501265_P039.Cel.gz    -0.000600    -0.001722     0.003114    1.0
# GSM7501234_P008.Cel.gz     0.004330    -0.003770    -0.000315    1.0
# GSM7501240_P014.Cel.gz    -0.000007     0.000338    -0.001387    1.0
# GSM7501236_P010.Cel.gz     0.002625    -0.002731     0.005434    1.0
# GSM7501243_P017.Cel.gz     0.000423    -0.001803    -0.000210    1.0
# ...                             ...          ...          ...    ...
# GSM7501232_P006.Cel.gz    -0.001267     0.000662    -0.001275    1.0
# GSM7501244_P018.Cel.gz     0.000857    -0.003281    -0.001940    1.0
# GSM7501251_P025.Cel.gz     0.004864    -0.015199    -0.011175    1.0
# GSM7501260_P034.Cel.gz     0.004515     0.000763    -0.008249    1.0
# GSM7501258_P032.Cel.gz     0.003625    -0.000805    -0.000940    1.0
#
# [235 rows x 75 columns]

# %%
len(['1561937_x_at', '201848_s_at', '202387_at', '202613_at', '202716_at',
       '203200_s_at', '205159_at', '205666_at', '209012_at', '210538_s_at',
       '210789_x_at', '211835_at', '212704_at', '213489_at', '213622_at',
       '217809_at', '217892_s_at', '220522_at', '222641_s_at', '223709_s_at',
       '223995_at', '225291_at', '225553_at', '225822_at', '226098_at',
       '226488_at', '228217_s_at', '231131_at', '232531_at', '234764_x_at',
       '235305_s_at', '237461_at', '238662_at', '36129_at', '41660_at',
       '57532_at'])
# Out:
# 36

# %%
h
# Out:
#                         1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# GSM7500929_S022.Cel.gz   2.970942  2.540097  2.811153  3.167094   1.859851
# GSM7500967_S060.Cel.gz   3.080110  2.607417  2.832051  3.173636   1.944836
# GSM7501250_P024.Cel.gz   3.036982  2.792590  2.705503  3.096431   1.947608
# GSM7501112_S205.Cel.gz   2.896482  2.891571  2.777735  3.047273   1.888281
# GSM7501179_S272.Cel.gz   3.029146  2.774474  2.689834  3.083803   1.821923
# ...                           ...       ...       ...       ...        ...
# GSM7500958_S051.Cel.gz   3.028635  2.601755  2.739391  3.164740   1.858359
# GSM7501191_S284.Cel.gz   2.957245  2.922407  2.567837  3.117989   1.806129
# GSM7501190_S283.Cel.gz   2.967770  2.768152  2.920354  3.104943   1.958380
# GSM7500916_S009.Cel.gz   3.035037  2.533448  2.738533  3.239142   1.878160
# GSM7501066_S159.Cel.gz   2.857701  2.769170  2.621366  3.071284   1.863269
#
#                          1294_at   1316_at   1320_at  1405_i_at   1431_at  \
# GSM7500929_S022.Cel.gz  2.981507  2.649470  2.452493   2.164694  2.325462
# GSM7500967_S060.Cel.gz  2.834856  2.598433  2.589627   2.396122  2.321166
# GSM7501250_P024.Cel.gz  3.081482  2.664559  2.410367   2.664863  2.227564
# GSM7501112_S205.Cel.gz  3.007692  2.589162  2.327968   2.542329  2.258676
# GSM7501179_S272.Cel.gz  3.017957  2.762779  2.330437   2.445325  2.314018
# ...                          ...       ...       ...        ...       ...
# GSM7500958_S051.Cel.gz  3.144240  2.506175  2.386776   2.258254  2.391451
# GSM7501191_S284.Cel.gz  3.155437  2.647167  2.408845   3.045906  2.319057
# GSM7501190_S283.Cel.gz  3.117634  2.764349  2.349062   2.762268  2.397019
# GSM7500916_S009.Cel.gz  3.029887  2.687321  2.460032   2.203923  2.351536
# GSM7501066_S159.Cel.gz  3.083524  2.598727  2.317396   2.168523  2.221165
#
#                         ...  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# GSM7500929_S022.Cel.gz  ...              3.426714             3.700699
# GSM7500967_S060.Cel.gz  ...              3.434808             3.748483
# GSM7501250_P024.Cel.gz  ...              3.542247             3.762080
# GSM7501112_S205.Cel.gz  ...              3.559228             3.760380
# GSM7501179_S272.Cel.gz  ...              3.607232             3.779516
# ...                     ...                   ...                  ...
# GSM7500958_S051.Cel.gz  ...              3.556292             3.781726
# GSM7501191_S284.Cel.gz  ...              3.601509             3.763328
# GSM7501190_S283.Cel.gz  ...              3.635147             3.783380
# GSM7500916_S009.Cel.gz  ...              3.566287             3.802075
# GSM7501066_S159.Cel.gz  ...              3.570474             3.752950
#
#                         AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  \
# GSM7500929_S022.Cel.gz             3.672691        2.399649        2.156773
# GSM7500967_S060.Cel.gz             3.733304        2.370733        2.238224
# GSM7501250_P024.Cel.gz             3.764720        3.377296        3.180466
# GSM7501112_S205.Cel.gz             3.777782        3.184481        2.940887
# GSM7501179_S272.Cel.gz             3.786268        2.325310        2.243745
# ...                                     ...             ...             ...
# GSM7500958_S051.Cel.gz             3.785276        2.249297        2.132350
# GSM7501191_S284.Cel.gz             3.771006        2.310461        2.197444
# GSM7501190_S283.Cel.gz             3.791693        2.317824        2.281833
# GSM7500916_S009.Cel.gz             3.800009        2.361376        2.221913
# GSM7501066_S159.Cel.gz             3.770032        3.202308        2.914829
#
#                         AFFX-ThrX-M_at  AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  \
# GSM7500929_S022.Cel.gz        2.015614         1.778271         1.944594
# GSM7500967_S060.Cel.gz        2.079923         1.777916         1.908668
# GSM7501250_P024.Cel.gz        3.240516         1.824881         1.991917
# GSM7501112_S205.Cel.gz        3.119600         1.883483         1.964275
# GSM7501179_S272.Cel.gz        2.035197         1.769868         1.917693
# ...                                ...              ...              ...
# GSM7500958_S051.Cel.gz        1.923675         1.747641         1.904742
# GSM7501191_S284.Cel.gz        2.014324         1.827527         1.931454
# GSM7501190_S283.Cel.gz        2.066512         1.787096         1.921082
# GSM7500916_S009.Cel.gz        2.094999         1.769342         1.950995
# GSM7501066_S159.Cel.gz        3.060972         1.821341         2.020655
#
#                         AFFX-TrpnX-M_at  state
# GSM7500929_S022.Cel.gz         2.066400    0.0
# GSM7500967_S060.Cel.gz         1.947770    0.0
# GSM7501250_P024.Cel.gz         1.953858    1.0
# GSM7501112_S205.Cel.gz         2.024373    0.0
# GSM7501179_S272.Cel.gz         1.935621    0.0
# ...                                 ...    ...
# GSM7500958_S051.Cel.gz         1.883827    0.0
# GSM7501191_S284.Cel.gz         1.822380    0.0
# GSM7501190_S283.Cel.gz         1.921439    0.0
# GSM7500916_S009.Cel.gz         2.018579    0.0
# GSM7501066_S159.Cel.gz         1.953581    0.0
#
# [358 rows x 54676 columns]

# %%
h
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
best = compare_models()

# %%
best
# Out:
# []

# %%
TX.to_csv('transformed_data.csv')
